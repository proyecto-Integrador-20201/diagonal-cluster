# %%
import numpy as np
import matplotlib.pyplot as plt
import boto3
import numpy as np 
# Esto es una prueba

# %%
X = np.random.randn(100, 3)

# %%
X
# Out:
# array([[ 5.38795718e-01,  1.06757525e+00, -2.83347814e-01],
#        [-4.11105080e-01,  6.14446249e-01,  2.46187430e-01],
#        [-4.73953881e-01, -1.78477856e+00, -6.56169657e-02],
#        [-5.09291198e-01, -1.60908043e+00, -4.98968996e-02],
#        [ 1.75655999e+00, -2.65627061e-01, -2.21123792e+00],
#        [ 1.72822290e-01, -2.97673641e-01, -1.98341780e+00],
#        [ 1.59178834e-01, -2.10225040e-01, -1.73495330e+00],
#        [-5.29294278e-01,  7.53202438e-01, -7.56905944e-01],
#        [ 1.30783650e-01,  1.26522177e-01,  8.58848380e-01],
#        [-1.50110159e+00,  6.12985774e-01,  1.70325740e-02],
#        [-7.21096097e-01,  1.85443778e-01,  7.21379583e-01],
#        [ 5.10822553e-01,  4.21977398e-01, -1.03545413e+00],
#        [-2.36091575e-01,  1.27404302e+00,  1.44040934e+00],
#        [ 1.57409752e-02, -1.95412786e+00, -1.56658072e+00],
#        [ 1.10285299e+00,  5.89061807e-01,  4.62853900e-01],
#        [ 7.18495261e-01, -1.16707493e+00, -9.04206671e-01],
# ...
