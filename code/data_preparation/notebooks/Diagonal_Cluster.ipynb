# %%
import numpy as np
import matplotlib.pyplot as plt
import boto3
import numpy as np

# %%
X = np.random.randn(100, 4)

# %%
X
# Out:
# array([[-1.45951034, -1.26041439,  1.67692355],
#        [-0.80549952, -0.70227878,  0.99796425],
#        [-0.41926079, -0.01113933,  1.50346339],
#        [ 1.12982903,  1.07606457,  1.41160114],
#        [-0.267018  , -0.08822282, -0.28158433],
#        [-1.94945361,  0.50037683,  0.38672823],
#        [ 1.55621821,  0.58236644,  0.2564098 ],
#        [ 0.11843081, -0.49796879, -1.05597886],
#        [-1.40475055, -0.25079675, -0.49849985],
#        [ 1.18410603,  0.87514901, -0.44749519],
#        [-0.54010169,  1.11290965,  0.38769603],
#        [ 0.42480906,  0.24821657, -0.75236677],
#        [ 0.13608244, -0.35627844, -0.6558155 ],
#        [ 1.30998496, -1.10275552, -0.49715658],
#        [-0.60959479,  0.0085389 , -0.29206531],
#        [ 0.56358657,  0.23181248, -0.03661982],
#        [ 0.83944652, -1.28554741,  0.74772351],
#        [ 0.87233051, -0.49903131,  0.98667957],
#        [ 1.81047878, -1.40584416, -0.66408836],
#        [-0.28881096, -0.45087204,  1.23900346],
# ...
